# %% [markdown]
# # Seção de Importação

# %%
#baixando o dataset de treino
# !wget --no-check-certificate https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip  -O /tmp/horse-or-human.zip
# Out:
# --2022-04-30 19:51:30--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 64.233.189.128, 108.177.97.128, 108.177.125.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|64.233.189.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘/tmp/horse-or-human.zip’
#
# /tmp/horse-or-human 100%[===================>] 142.65M   203MB/s    in 0.7s
#
# 2022-04-30 19:51:32 (203 MB/s) - ‘/tmp/horse-or-human.zip’ saved [149574867/149574867]

# %%
#baixando o dataset de teste
# !wget --no-check-certificate https://storage.googleapis.com/laurencemoroney-blog.appspot.com/validation-horse-or-human.zip  -O /tmp/validation-horse-or-human.zip
# Out:
# --2022-04-30 19:51:32--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/validation-horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.23.128, 74.125.204.128, 64.233.189.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.23.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11480187 (11M) [application/zip]
# Saving to: ‘/tmp/validation-horse-or-human.zip’
#
# /tmp/validation-hor 100%[===================>]  10.95M  --.-KB/s    in 0.1s
#
# 2022-04-30 19:51:32 (114 MB/s) - ‘/tmp/validation-horse-or-human.zip’ saved [11480187/11480187]

# %%
import os
import zipfile

#extraindo o zip

local_zip = '/tmp/horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/horse-or-human')
zip_ref.close()

# %%
#extraindo os arquivos para validação

local_zip = '/tmp/validation-horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/validation-horse-or-human')
zip_ref.close()

# %%
# Diretorio com as imagens de treino de cavalos
train_horse_dir = os.path.join('/tmp/horse-or-human/horses')


 
# Diretorio com as imagens de treino de humanos
train_human_dir = os.path.join('/tmp/horse-or-human/humans')

# %%
#Diretorio para os arquivos da validação

test_horse_dir = os.path.join('/tmp/validation-horse-or-human/horses')
test_human_dir = os.path.join('/tmp/validation-horse-or-human/humans')

# %% [markdown]
# # Seção de visualização dos dados

# %%
#nomes dos arquivos
train_horse_names = os.listdir(train_horse_dir)
print(train_horse_names[:10])
train_human_names = os.listdir(train_human_dir)
print(train_human_names[:10])
# Out:
# ['horse22-0.png', 'horse22-2.png', 'horse14-6.png', 'horse21-7.png', 'horse35-3.png', 'horse31-2.png', 'horse33-3.png', 'horse26-3.png', 'horse08-4.png', 'horse24-4.png']
# ['human04-19.png', 'human07-24.png', 'human10-08.png', 'human14-05.png', 'human14-24.png', 'human11-13.png', 'human04-05.png', 'human10-07.png', 'human03-23.png', 'human12-07.png']

# %%
test_horse_names = os.listdir(test_horse_dir)
print(test_horse_names[:10])
test_human_names = os.listdir(test_human_dir)
print(test_human_names[:10])
# Out:
# ['horse5-018.png', 'horse2-412.png', 'horse1-568.png', 'horse6-064.png', 'horse5-100.png', 'horse6-089.png', 'horse2-224.png', 'horse3-011.png', 'horse4-530.png', 'horse1-127.png']
# ['valhuman03-10.png', 'valhuman05-06.png', 'valhuman04-19.png', 'valhuman01-10.png', 'valhuman02-01.png', 'valhuman02-20.png', 'valhuman04-06.png', 'valhuman02-04.png', 'valhuman01-07.png', 'valhuman05-21.png']

# %%
#total de imagens
print('total training horse images:', len(os.listdir(train_horse_dir)))
print('total training human images:', len(os.listdir(train_human_dir)))
# Out:
# total training horse images: 500
# total training human images: 527

# %%
print('total training horse images:', len(os.listdir(test_horse_dir)))
print('total training human images:', len(os.listdir(test_human_dir)))
# Out:
# total training horse images: 128
# total training human images: 128

# %%
# %matplotlib inline
 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
 
# Parametros para o nosso gráfico
nrows = 4
ncols = 4
 

pic_index = 0

# %%
# Criação do gráfico
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)
 
pic_index += 8
next_horse_pix = [os.path.join(train_horse_dir, fname) 
                for fname in train_horse_names[pic_index-8:pic_index]]
next_human_pix = [os.path.join(train_human_dir, fname) 
                for fname in train_human_names[pic_index-8:pic_index]]
 
for i, img_path in enumerate(next_horse_pix+next_human_pix):
  
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)
 
  img = mpimg.imread(img_path)
  plt.imshow(img)
 
plt.show()

# %% [markdown]
# # Seção de Treinamento

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([

    # Primeira convolução
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # Segunda convolução
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Terceira convolução
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Quarta convolução
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Quinta convolução
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    # Usamos apenas um neurônio como saída, sendo 0 para cavalos e 1 para humanos
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 298, 298, 16)      448
#
#  max_pooling2d_10 (MaxPoolin  (None, 149, 149, 16)     0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 147, 147, 32)      4640
#
#  max_pooling2d_11 (MaxPoolin  (None, 73, 73, 32)       0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 71, 71, 64)        18496
#
#  max_pooling2d_12 (MaxPoolin  (None, 35, 35, 64)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 33, 33, 64)        36928
#
#  max_pooling2d_13 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 64)        36928
#
#  max_pooling2d_14 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 3136)              0
#
#  dense_4 (Dense)             (None, 512)               1606144
#
#  dense_5 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1,704,097
# Trainable params: 1,704,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop
 
model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(learning_rate=0.001),
              metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
 
train_generator = train_datagen.flow_from_directory(
        '/tmp/horse-or-human/',  # This is the source directory for training images
        target_size=(300, 300),  # All images will be resized to 150x150
        batch_size=128,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
# Out:
# Found 1027 images belonging to 2 classes.

# %%
epochs_hist = model.fit(
      train_generator,
      steps_per_epoch=8,  
      epochs=15,
      verbose=1)
# Out:
# Epoch 1/15
# 8/8 [==============================] - 8s 983ms/step - loss: 1.0465 - accuracy: 0.5039
# Epoch 2/15
# 8/8 [==============================] - 7s 800ms/step - loss: 0.6677 - accuracy: 0.5907
# Epoch 3/15
# 8/8 [==============================] - 7s 832ms/step - loss: 0.5991 - accuracy: 0.7386
# Epoch 4/15
# 8/8 [==============================] - 7s 830ms/step - loss: 1.1046 - accuracy: 0.7753
# Epoch 5/15
# 8/8 [==============================] - 7s 847ms/step - loss: 0.3564 - accuracy: 0.8576
# Epoch 6/15
# 8/8 [==============================] - 7s 831ms/step - loss: 0.1798 - accuracy: 0.9344
# Epoch 7/15
# 8/8 [==============================] - 7s 836ms/step - loss: 0.2217 - accuracy: 0.8943
# Epoch 8/15
# 8/8 [==============================] - 7s 835ms/step - loss: 0.1195 - accuracy: 0.9655
# Epoch 9/15
# 8/8 [==============================] - 7s 831ms/step - loss: 1.1495 - accuracy: 0.8565
# Epoch 10/15
# 8/8 [==============================] - 7s 831ms/step - loss: 0.1941 - accuracy: 0.9522
# Epoch 11/15
# 8/8 [==============================] - 7s 971ms/step - loss: 0.0389 - accuracy: 0.9878
# Epoch 12/15
# 8/8 [==============================] - 7s 841ms/step - loss: 0.0363 - accuracy: 0.9878
# Epoch 13/15
# 8/8 [==============================] - 7s 838ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 14/15
# 8/8 [==============================] - 7s 833ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 7s 797ms/step - loss: 0.0078 - accuracy: 0.9967

# %% [markdown]
# # Seção de Teste/Validação

# %%
import numpy as np
from keras.preprocessing import image


#uma função para testar o nosso dataset de testes
def pred_human_horse(model, horse_or_human):
  test_image = image.load_img(horse_or_human, target_size = (300, 300))
  test_image = image.img_to_array(test_image)/255
  test_image = np.expand_dims(test_image, axis = 0)

  result = model.predict(test_image).round(3)

  pred = np.argmax(result)
  print(horse_or_human,"--->", result)

  if result>0.5:
    print('Predicted>>> Human')
  else:
    print('Predicted>>> Horse')

# %%
import os

#Teste com cavalos
lista_val = [os.path.join(test_horse_dir, nome) for nome in os.listdir(test_horse_dir)]

for horse_or_human in lista_val:
  pred_human_horse(model, horse_or_human)
# Out:
# /tmp/validation-horse-or-human/horses/horse5-018.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-412.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-568.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse6-064.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-100.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse6-089.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-224.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-011.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-530.png ---> [[0.905]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-127.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-521.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-099.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-070.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-188.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-264.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse5-235.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-326.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-241.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse2-596.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-554.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-360.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-342.png ---> [[0.033]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse2-544.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-294.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-198.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-584.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse4-159.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-032.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-060.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-405.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-484.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-495.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-335.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse6-403.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-400.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-204.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-541.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse2-441.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-002.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-588.png ---> [[0.998]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-455.png ---> [[0.862]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse6-275.png ---> [[0.976]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-550.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-224.png ---> [[0.985]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-539.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-069.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-504.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-170.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-255.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-123.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-011.png ---> [[0.999]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-599.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-458.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse2-383.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-440.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse1-298.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse5-065.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-141.png ---> [[0.674]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-203.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-026.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse6-004.png ---> [[0.159]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse2-201.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-469.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-498.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-589.png ---> [[0.975]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-276.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse3-171.png ---> [[0.165]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse4-389.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-416.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse4-501.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse6-544.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-582.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse6-345.png ---> [[0.987]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-411.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse1-436.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse5-083.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-043.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-403.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse4-202.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-565.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-000.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-488.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse3-217.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-402.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-303.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse6-161.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-484.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-000.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-103.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-181.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-556.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-519.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-102.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-314.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-105.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-302.png ---> [[0.638]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-541.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-275.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-259.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-269.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-040.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-136.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse6-153.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-014.png ---> [[0.659]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse1-122.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-368.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-076.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-055.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-468.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse1-510.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-218.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-254.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-478.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse1-384.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse5-164.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse6-218.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse4-232.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-192.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-548.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse3-397.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-072.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-345.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse5-514.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse6-198.png ---> [[0.]]
# Predicted>>> Horse
# /tmp/validation-horse-or-human/horses/horse4-503.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-112.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse2-183.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/horses/horse4-439.png ---> [[0.]]
# Predicted>>> Horse

# %%
#Teste com humanos
lista_val = [os.path.join(test_human_dir, nome) for nome in os.listdir(test_human_dir)]

for horse_or_human in lista_val:
  pred_human_horse(model, horse_or_human)
# Out:
# /tmp/validation-horse-or-human/humans/valhuman03-10.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-06.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-19.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-10.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-01.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-20.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-06.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-04.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-07.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-21.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-13.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-21.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-14.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-04.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-19.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-05.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-19.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-26.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-18.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-20.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-13.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-17.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-08.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-14.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-18.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-16.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-15.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-16.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-19.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-14.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-23.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-22.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-06.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-27.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-08.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-23.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-03.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-00.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-12.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-13.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-15.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-02.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-15.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-22.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-06.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-21.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-05.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-01.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-11.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-07.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-03.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-03.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-17.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-12.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-05.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-03.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-04.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-21.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-24.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-00.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-24.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-18.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-02.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-11.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-04.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-10.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-01.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-10.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-20.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-24.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-13.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-09.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-19.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-14.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-24.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-02.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-11.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-12.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-11.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-20.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-09.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-18.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-20.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-01.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-03.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-09.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-00.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-16.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-12.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-08.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-00.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-09.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-23.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-00.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-17.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-14.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-24.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-17.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-10.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-08.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-23.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-22.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-23.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-05.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-06.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-12.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-09.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman02-07.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-11.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-04.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-08.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-21.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-07.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-13.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-16.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-02.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-15.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-07.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-25.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-02.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-22.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-01.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-16.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-17.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman01-18.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman03-05.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman05-15.png ---> [[1.]]
# Predicted>>> Human
# /tmp/validation-horse-or-human/humans/valhuman04-22.png ---> [[1.]]
# Predicted>>> Human

# %% [markdown]
# # Gráfico de Métricas de Desempenho

# %%
import pandas as pd

history_df = pd.DataFrame(epochs_hist.history)

history_df['loss'].plot();
history_df['accuracy'].plot();

plt.title('Métricas de desempenho')
plt.ylabel('Accuracy & Loss')
plt.xlabel('epoch or iteration')
plt.legend(["loss", 'accuracy'], loc = 'upper left')
plt.show()

# %% [markdown]
# # Features Extras Interessantes

# %%
#Visualização das layers

import numpy as np
import random
from tensorflow.keras.preprocessing.image import img_to_array, load_img
 

successive_outputs = [layer.output for layer in model.layers[1:]]

visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)

horse_img_files = [os.path.join(train_horse_dir, f) for f in train_horse_names]
human_img_files = [os.path.join(train_human_dir, f) for f in train_human_names]
img_path = random.choice(horse_img_files + human_img_files)
 
img = load_img(img_path, target_size=(300, 300))
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
 

x /= 255
 

successive_feature_maps = visualization_model.predict(x)
layer_names = [layer.name for layer in model.layers]
 

for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  if len(feature_map.shape) == 4:
    
    n_features = feature_map.shape[-1]  
    
    size = feature_map.shape[1]
    
    display_grid = np.zeros((size, size * n_features))
    for i in range(n_features):
      
      x = feature_map[0, :, :, i]
      x -= x.mean()
      if x.std()>0:
        x /= x.std()
      x *= 64
      x += 128
      x = np.clip(x, 0, 255).astype('uint8')
      
      display_grid[:, i * size : (i + 1) * size] = x
    
    scale = 20. / n_features
    plt.figure(figsize=(scale * n_features, scale))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')

# %%
#teste passando um arquivo qualquer sem necessidade de alteração do código

import numpy as np
from google.colab import files
from keras.preprocessing import image
 
uploaded = files.upload()
 
for fn in uploaded.keys():
 
  path = '/content/' + fn
  img = image.load_img(path, target_size=(300, 300))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
 
  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn + " is a human")
  else:
    print(fn + " is a horse")
# Out:
#      <input type="file" id="files-04749068-cda8-4354-890a-36b36b336436" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04749068-cda8-4354-890a-36b36b336436">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving valhuman05-23.png to valhuman05-23.png
# [1.]
# valhuman05-23.png is a human
